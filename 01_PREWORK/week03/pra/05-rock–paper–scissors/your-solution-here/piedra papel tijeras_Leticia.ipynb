# %% [markdown]
# # Piedra, papel, tijeras
#
# Vamos jugar contra nuestro ordenador al famoso juego.
#
# https://es.wikipedia.org/wiki/Piedra,_papel_o_tijera
#
# Se aconseja el uso de funciones

# %%
# Importa la función choice del módulo random
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Asigna a una lista las 3 posibles opciones: 'piedra', 'papel' o 'tijeras'. 

game = ["piedra", "papel", "tijeras"]

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...

num_games = 5

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas

game_win = 3

# Define una función que devuelva aleatoriamente una de las 3 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 

def pc_play():
    return(random.choice(game))

# Define una función que pregunte tu elección: 'piedra', 'papel' o 'tijeras'
# sólo debe permitir una de las 3 opciones. Esto es programación defensiva. 
# Si no es piedra, papel o tijeras sigue preguntando hasta que lo sea. 

def user_play():
    n = input("¿Qué eliges?")
    if n == "piedra" or n == "papel" or n == "tijeras":
        return n
    else: 
        print("Debes elegir entre piedra, papel o tijeras. Inténtalo de nuevo: ")


# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano 

# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
    
# Crea dos variables que acumulen las partidas ganadas de cada participante

# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 

    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas

def combate(user, pc):
    partidas = -1
    empate = []
    user_win = []
    pc_win = []
    while partidas <= game_win:
        user = user_play()
        pc = pc_play()
        if user == pc:
            empate.append(1)
            partidas += 1
            resultado = 0
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "tijeras" and pc == "papel":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "tijeras" and pc == "piedra":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "papel" and pc == "piedra":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "piedra" and pc == "papel":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "piedra" and pc == "tijeras":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "papel" and pc == "tijeras":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")

    if len(pc_win) > len(user_win):
        print("PC GANADOR")
        return 1
    elif len(user_win) > len(pc_win):
        print("USER GANADOR")
        return 2
    else:
        print("¿DESEMPATAMOS?")
        combate(user,pc)

# %%
combate(user_play,pc_play)
# Out:
# Partida 1 - pc: tijeras X user: piedra - Resultado: 2
# Partida 2 - pc: papel X user: papel - Resultado: 0
# Partida 3 - pc: papel X user: piedra - Resultado: 1
# Partida 4 - pc: piedra X user: tijeras - Resultado: 1
# Partida 5 - pc: tijeras X user: papel - Resultado: 1
# PC GANADOR
# 1

# %% [markdown]
# # Bonus: Piedra, papel, tijeras, lagarto, spock
#
# Ahora vienen las mejoras.
#
# http://www.samkass.com/theories/RPSSL.html
#
# Se te pide que implimentes unas mejoras con respecto al simple juego previo. Además el número de partidas (que deberá ser IMPAR) se pedirá por consola hasta que se introduzca un número válido.
#
# Mejoras:
# * 5 opciones: piedra, papel, tijeras, lagarto, spock
# * El número de partidas se pide por consola
# Consejo: Reutiliza código que ya hagas utilizado

# %%
# Importa la función choice del módulo random
import random

# Define una función que pide por teclado un número impar, hasta que no sea válido
# seguirá pidiendo

def num_partidas():
    n = int(input("Introduce un número ímpar entero"))
    if n % 2 == 0:
        num_partidas ()
    else:
        return n

# Asigna a una lista las 5 posibles opciones. 

game = ["piedra", "papel", "tijeras", "lagarto", "spock"]

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
# Esta vez se usa la función definida previamente

#num_games = num_partidas()

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas

game_win = (num_partidas()//2)+1

# Define una función que devuelva aleatoriamente una de las 5 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 

def pc_play():
    return(random.choice(game))

# Define una función que pregunte tu elección de entre las 5
# sólo debe permitir una de las 5 opciones. Esto es programación defensiva. 
# Si no es válida sigue preguntando hasta que lo sea. 

def user_play():
    n = input("¿Qué eliges?")
    if n == "piedra" or n == "papel" or n == "tijeras" or n == "lagarto" or n == "spock":
        return n
    else: 
        print("Debes elegir entre piedra, papel o tijeras. Inténtalo de nuevo: ")

# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano
# Ahora hay más opciones
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
# Crea dos variables que acumulen las partidas ganadas de cada participante
# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas

def combate_pro(user, pc):

    partidas = -1
    empate = []
    user_win = []
    pc_win = []

    while partidas <= game_win:
        user = user_play()
        pc = pc_play()
        if user == pc:
            empate.append(1)
            partidas += 1
            resultado = 0
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "papel" and pc == "piedra":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "spock" and pc == "piedra":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "tijeras" and pc == "lagarto":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "piedra" and pc == "lagarto":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "lagarto" and pc == "spock":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "papel" and pc == "spock":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "spock" and pc == "tijeras":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "piedra" and pc == "tijeras":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "lagarto" and pc == "papel":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif user == "tijeras" and pc == "papel":
            user_win.append(1)
            partidas += 1
            resultado = 2
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "papel" and user == "piedra":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "spock" and user == "piedra":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "tijeras" and user == "lagarto":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "piedra" and user == "lagarto":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "lagarto" and user == "spock":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "papel" and user == "spock":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "spock" and user == "tijeras":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "piedra" and user == "tijeras":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "lagarto" and user == "papel":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")
        elif pc == "tijeras" and user == "papel":
            pc_win.append(1)
            partidas += 1
            resultado = 1
            print(f"Partida {partidas+1} - pc: {pc} X user: {user} - Resultado: {resultado}")

    if len(pc_win) > len(user_win):
        print("PC GANADOR")
        return 1
    elif len(user_win) > len(pc_win):
        print("USER GANADOR")
        return 2
    else:
        print("¿DESEMPATAMOS?")
        combate_pro(user,pc)

# %%
combate_pro(user_play,pc_play)
# Out:
# Partida 1 - pc: piedra X user: papel - Resultado: 2
# Partida 2 - pc: piedra X user: tijeras - Resultado: 1
# Partida 3 - pc: spock X user: spock - Resultado: 0
# Partida 4 - pc: lagarto X user: lagarto - Resultado: 0
# ¿DESEMPATAMOS?
# Partida 1 - pc: piedra X user: papel - Resultado: 2
# Partida 2 - pc: papel X user: tijeras - Resultado: 2
# Partida 3 - pc: piedra X user: papel - Resultado: 2
# Partida 4 - pc: tijeras X user: piedra - Resultado: 2
# USER GANADOR

# %% [markdown]
# Si has programado con cabeza, el bonus son simples modificaciones al juego original.

# %% [markdown]
# ## Objetivos
# 1. Uso de bucle
# 2. Captura de datos por consola
# 3. Uso if-elif-else
# 4. Uso de try-except
# 5. Definición de funciones. Programación modular.
# 6. Operadores lógicos.
# 7. Imprimir por consola
# 8. Importación de módulos externos
