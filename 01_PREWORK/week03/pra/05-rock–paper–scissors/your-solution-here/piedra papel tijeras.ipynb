# %% [markdown]
# # Piedra, papel, tijeras
#
# Vamos jugar contra nuestro ordenador al famoso juego.
#
# https://es.wikipedia.org/wiki/Piedra,_papel_o_tijera
#
# Se aconseja el uso de funciones

# %%
# Importa la función choice del módulo random
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Asigna a una lista las 3 posibles opciones: 'piedra', 'papel' o 'tijeras'. 
opciones = ['piedra','papel','tijeras']

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
partidas_max = 3

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas
partidas_ganar = int(partidas_max/2 + 1)

# Define una función que devuelva aleatoriamente una de las 3 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 
def jugada_maquina():
    return(random.choice(opciones))

# Define una función que pregunte tu elección: 'piedra', 'papel' o 'tijeras'
# sólo debe permitir una de las 3 opciones. Esto es programación defensiva. 
# Si no es piedra, papel o tijeras sigue preguntando hasta que lo sea. 
def jugada_humano():
    jugada = input(f'Seleccione {opciones}')
    while (jugada != 'papel') and (jugada !='piedra') and (jugada !='tijeras'):
        jugada = input(f'Opción no válida, seleccione {opciones}')
    return(jugada)
        

# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano 
def combate(x,y):
    if (x == 'tijeras' and y == 'tijeras') or (
        x == 'papel' and y == 'papel') or (
        x == 'piedra' and y == 'piedra'):
        return(int(0))
    elif x == 'tijeras' and y == 'papel':
        return(int(1))
    elif x == 'tijeras' and y == 'piedra':
        return(int(2))
    elif x == 'papel' and y == 'piedra':
        return(int(1))
    elif x == 'papel' and y == 'tijeras':
        return(int(2))
    elif x == 'piedra' and y == 'papel':
        return(int(1))
    elif x == 'piedra' and y == 'tijeras':
        return(int(2))
    
    
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados

def partida(a,b,c):
    print(f'La maquina ha elegido {a}')
    print(f'El humano ha elegido {b}')
    if c == 0:
        print('Esta partida ha sido empate')
    elif c == 1:
        print('Esta partida gana la maquina')
    else:
        print('Esta partida gana el humano')

    
# Crea dos variables que acumulen las partidas ganadas de cada participante
victorias_maquina = 0
victorias_humano = 0

# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 


while (victorias_humano < partidas_ganar) and (victorias_maquina < partidas_ganar):
    maquina = jugada_maquina()
    humano = jugada_humano()
    duelo = combate(maquina,humano)

    partida(maquina,humano,duelo)

    if duelo == 1:
        victorias_maquina +=1
    elif duelo == 2:
        victorias_humano +=1
    print(f'Marcador: humano = {victorias_humano} : {victorias_maquina} = maquina')
    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas
if victorias_humano > victorias_maquina:
    print('El humano gana el juego')
else:
    print('La maquina gana el juego')
# Out:
# La maquina ha elegido piedra
# El humano ha elegido papel
# Esta partida gana la maquina
# Marcador: humano = 0 : 1 = maquina
# La maquina ha elegido tijeras
# El humano ha elegido papel
# Esta partida gana la maquina
# Marcador: humano = 0 : 2 = maquina
# La maquina gana el juego

# %% [markdown]
# # Bonus: Piedra, papel, tijeras, lagarto, spock
#
# Ahora vienen las mejoras.
#
# http://www.samkass.com/theories/RPSSL.html
#
# Se te pide que implimentes unas mejoras con respecto al simple juego previo. Además el número de partidas (que deberá ser IMPAR) se pedirá por consola hasta que se introduzca un número válido.
#
# Mejoras:
# * 5 opciones: piedra, papel, tijeras, lagarto, spock
# * El número de partidas se pide por consola
# Consejo: Reutiliza código que ya hagas utilizado

# %%
# Importa la función choice del módulo random
import random

# Define una función que pide por teclado un número impar, hasta que no sea válido
# seguirá pidiendo
def num_impar():
    impar = int(input(f'Seleccione un número impar'))
    while impar%2 == 0:
         impar = input(f'Seleccione un número impar')
    return(impar)

# Asigna a una lista las 5 posibles opciones. 
opciones_bonus = ['piedra','papel','tijeras','lagarto', 'spock']

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
# Esta vez se usa la función definida previamente
num_partidas = num_impar()

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas
partidas_ganar_bonus = int((num_partidas/2)+1)

# Define una función que devuelva aleatoriamente una de las 5 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 

def jugada_maquina_bonus():
    return(random.choice(opciones_bonus))

# Define una función que pregunte tu elección de entre las 5
# sólo debe permitir una de las 5 opciones. Esto es programación defensiva. 
# Si no es válida sigue preguntando hasta que lo sea. 
def jugada_humano_bonus():
    jugada_bonus = input(f'Seleccione {opciones_bonus}')
    while (jugada_bonus != 'papel') and (jugada_bonus !='piedra') and (jugada_bonus !='tijeras') and (jugada_bonus !='lagarto') and (jugada_bonus !='spock'):
        jugada_bonus = input(f'Opción no válida, seleccione {opciones_bonus}')
    return(jugada_bonus)

# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano
# Ahora hay más opciones
def combate_bonus(x,y):
    if (x == 'tijeras' and y == 'tijeras') or (
        x == 'papel' and y == 'papel') or (
        x == 'piedra' and y == 'piedra') or (
        x == 'lagarto' and y == 'lagarto' or (
        x == 'spock' and y == 'spock')):
        return(int(0))
    elif x == 'tijeras' and y == 'papel':
        return(int(1))
    elif x == 'tijeras' and y == 'piedra':
        return(int(2))
    elif x == 'tijeras' and y == 'lagarto':
        return(int(1))
    elif x == 'tijeras' and y == 'spock':
        return(int(2))
    elif x == 'papel' and y == 'piedra':
        return(int(1))
    elif x == 'papel' and y == 'tijeras':
        return(int(2))
    elif x == 'papel' and y == 'lagarto':
        return(int(2))
    elif x == 'papel' and y == 'spock':
        return(int(1))
    elif x == 'piedra' and y == 'papel':
        return(int(1))
    elif x == 'piedra' and y == 'tijeras':
        return(int(2))
    elif x == 'piedra' and y == 'lagarto':
        return(int(1))
    elif x == 'piedra' and y == 'spock':
        return(int(2))
    elif x == 'lagarto' and y == 'papel':
        return(int(1))
    elif x == 'lagarto' and y == 'tijeras':
        return(int(2))
    elif x == 'lagarto' and y == 'piedra':
        return(int(2))
    elif x == 'lagarto' and y == 'spock':
        return(int(1))
    elif x == 'spock' and y == 'papel':
        return(int(2))
    elif x == 'spock' and y == 'tijeras':
        return(int(1))
    elif x == 'spock' and y == 'piedra':
        return(int(1))
    elif x == 'spock' and y == 'lagarto':
        return(int(2))

    
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
def partida(a,b,c):
    print(f'La maquina ha elegido {a}')
    print(f'El humano ha elegido {b}')
    if c == 0:
        print('Esta partida ha sido empate')
    elif c == 1:
        print('Esta partida gana la maquina')
    else:
        print('Esta partida gana el humano')

    
# Crea dos variables que acumulen las partidas ganadas de cada participante
victorias_maquina_bonus = 0
victorias_humano_bonus = 0

# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 
while (victorias_humano_bonus < partidas_ganar_bonus) and (victorias_maquina_bonus < partidas_ganar_bonus):
    maquina_bonus = jugada_maquina_bonus()
    humano_bonus = jugada_humano_bonus()
    duelo_bonus = combate_bonus(maquina_bonus,humano_bonus)

    partida(maquina_bonus,humano_bonus,duelo_bonus)

    if duelo_bonus == 1:
        victorias_maquina_bonus +=1
    elif duelo_bonus == 2:
        victorias_humano_bonus +=1
    print(f'Marcador: humano = {victorias_humano_bonus} : {victorias_maquina_bonus} = maquina')

    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas
if victorias_humano_bonus > victorias_maquina_bonus:
    print('El humano gana el juego')
else:
    print('La maquina gana el juego')
# Out:
# La maquina ha elegido spock
# El humano ha elegido piedra
# Esta partida gana la maquina
# Marcador: humano = 0 : 1 = maquina
# La maquina ha elegido tijeras
# El humano ha elegido spock
# Esta partida gana el humano
# Marcador: humano = 1 : 1 = maquina
# La maquina ha elegido spock
# El humano ha elegido spock
# Esta partida ha sido empate
# Marcador: humano = 1 : 1 = maquina
# La maquina ha elegido piedra
# El humano ha elegido lagarto
# Esta partida gana la maquina
# Marcador: humano = 1 : 2 = maquina
# La maquina ha elegido piedra
# El humano ha elegido lagarto
# Esta partida gana la maquina
# Marcador: humano = 1 : 3 = maquina
# La maquina gana el juego

# %% [markdown]
# Si has programado con cabeza, el bonus son simples modificaciones al juego original.

# %% [markdown]
# ## Objetivos
# 1. Uso de bucle
# 2. Captura de datos por consola
# 3. Uso if-elif-else
# 4. Uso de try-except
# 5. Definición de funciones. Programación modular.
# 6. Operadores lógicos.
# 7. Imprimir por consola
# 8. Importación de módulos externos
