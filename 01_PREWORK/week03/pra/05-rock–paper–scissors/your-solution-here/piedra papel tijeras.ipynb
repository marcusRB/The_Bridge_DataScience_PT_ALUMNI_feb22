# %% [markdown]
# # Piedra, papel, tijeras
#
# Vamos jugar contra nuestro ordenador al famoso juego.
#
# https://es.wikipedia.org/wiki/Piedra,_papel_o_tijera
#
# Se aconseja el uso de funciones

# %%
# Importa la función choice del módulo random
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
from random import choice

# Asigna a una lista las 3 posibles opciones: 'piedra', 'papel' o 'tijeras'. 
opciones = ['piedra', 'papel', 'tijeras']

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
max_partidas = 3

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas
ganar_juego = int(max_partidas/2) + 1

# Define una función que devuelva aleatoriamente una de las 3 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 
def ele_maquina():
    return choice(opciones)

# Define una función que pregunte tu elección: 'piedra', 'papel' o 'tijeras'
# sólo debe permitir una de las 3 opciones. Esto es programación defensiva. 
# Si no es piedra, papel o tijeras sigue preguntando hasta que lo sea. 
def ele_jugador():
    eleccion = input("¿piedra, papel o tijeras?")
    
    while eleccion not in opciones:
        eleccion = input("¿piedra, papel o tijeras?")

    return eleccion

# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano 
def combate(maquina, jugador):
    if maquina == 'piedra' and jugador == 'tijeras':
        return 1
    elif maquina == 'papel' and jugador == 'piedra':
        return 1
    elif maquina == 'tijeras' and jugador == 'papel':
        return 1
    elif maquina == jugador:
        return 0
    else:
        return 2
    
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
def estado_partida(ele_maquina, ele_jugador, part_maquina, part_jugador):
    print(f"El jugador ha elegido jugar {ele_jugador} y la maquina {ele_maquina}")
    print("----------------------------------------------------------------------")
    print(f"partidas ganadas: {part_jugador} el jugador vs {part_maquina} la maquina")

    
# Crea dos variables que acumulen las partidas ganadas de cada participante
part_maquina, part_jugador = 0, 0

# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 
while part_maquina < ganar_juego and part_jugador < ganar_juego:

    maquina, jugador = ele_maquina(), ele_jugador()
    res = combate(maquina, jugador)
    
    if res == 1:
        part_maquina += 1
        estado_partida(maquina, jugador, part_maquina, part_jugador)
    elif res == 2: 
        part_jugador += 1
        estado_partida(maquina, jugador, part_maquina, part_jugador)
    elif res == 0:
        print("EMPATE!")
        estado_partida(maquina, jugador, part_maquina, part_jugador)
    else:
        print("Error en el combate")

    print()
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas

if part_jugador == ganar_juego:
    print("HA GANADO EL JUGADOR! FELICIDADES")
elif part_maquina == ganar_juego:
    print("HA GANADO LA MAQUINA! Suerte para la próxima :( ")
else:
    print("Error en la partida")
# Out:
# El jugador ha elegido jugar piedra y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 1 el jugador vs 0 la maquina
#
# El jugador ha elegido jugar piedra y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 2 el jugador vs 0 la maquina
#
# HA GANADO EL JUGADOR! FELICIDADES

# %% [markdown]
# # Bonus: Piedra, papel, tijeras, lagarto, spock
#
# Ahora vienen las mejoras.
#
# http://www.samkass.com/theories/RPSSL.html
#
# Se te pide que implimentes unas mejoras con respecto al simple juego previo. Además el número de partidas (que deberá ser IMPAR) se pedirá por consola hasta que se introduzca un número válido.
#
# Mejoras:
# * 5 opciones: piedra, papel, tijeras, lagarto, spock
# * El número de partidas se pide por consola
# Consejo: Reutiliza código que ya hagas utilizado

# %%
# Importa la función choice del módulo random
from random import choice

# Define una función que pide por teclado un número impar, hasta que no sea válido
# seguirá pidiendo
def fun_max_partidas():
    max_partidas = int(input("Teclea un número impar"))

    while max_partidas % 2 == 0:
        max_partidas = input("Teclea un número impar")
    
    return max_partidas
# Asigna a una lista las 5 posibles opciones. 
opciones = ['piedra', 'papel', 'tijeras', 'lagarto', 'spock']

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
# Esta vez se usa la función definida previamente
max_partidas = fun_max_partidas()

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas
ganar_juego = int(max_partidas/2) + 1

# Define una función que devuelva aleatoriamente una de las 5 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 
def ele_maquina():
    return choice(opciones)

# Define una función que pregunte tu elección de entre las 5
# sólo debe permitir una de las 5 opciones. Esto es programación defensiva. 
# Si no es válida sigue preguntando hasta que lo sea. 
def ele_jugador():
    eleccion = input("piedra, papel, tijeras, lagarto, spock")
    
    while eleccion not in opciones:
        eleccion = input("piedra, papel, tijeras, lagarto, spock")

    return eleccion

# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano
# Ahora hay más opciones
def combate(maquina, jugador):
    if maquina == 'piedra' and jugador == 'tijeras' or jugador == 'lagarto' :
        return 1
    elif maquina == 'papel' and jugador == 'piedra' or jugador == 'spock':
        return 1
    elif maquina == 'tijeras' and jugador == 'papel' or jugador == 'lagarto':
        return 1
    elif maquina == 'lagarto' and jugador == 'papel' or jugador == 'spock':
        return 1
    elif maquina == 'spock' and jugador == 'tijeras' or jugador == 'piedra':
        return 1
    elif maquina == jugador:
        return 0
    else:
        return 2
   
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
def estado_partida(ele_maquina, ele_jugador, part_maquina, part_jugador):
    print(f"El jugador ha elegido jugar {ele_jugador} y la maquina {ele_maquina}")
    print("----------------------------------------------------------------------")
    print(f"partidas ganadas: {part_jugador} el jugador vs {part_maquina} la maquina")

# Crea dos variables que acumulen las partidas ganadas de cada participante
part_maquina, part_jugador = 0, 0

# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 
while part_maquina < ganar_juego and part_jugador < ganar_juego:

    maquina, jugador = ele_maquina(), ele_jugador()
    res = combate(maquina, jugador)
    
    if res == 1:
        part_maquina += 1
        estado_partida(maquina, jugador, part_maquina, part_jugador)
    elif res == 2: 
        part_jugador += 1
        estado_partida(maquina, jugador, part_maquina, part_jugador)
    elif res == 0:
        print("EMPATE!")
        estado_partida(maquina, jugador, part_maquina, part_jugador)
    else:
        print("Error en el combate")

    print()
      
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas
if part_jugador == ganar_juego:
    print("HA GANADO EL JUGADOR! FELICIDADES")
elif part_maquina == ganar_juego:
    print("HA GANADO LA MAQUINA! Suerte para la próxima :( ")
else:
    print("Error en la partida")
# Out:
# El jugador ha elegido jugar spock y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 1 la maquina
#
# El jugador ha elegido jugar spock y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 2 la maquina
#
# El jugador ha elegido jugar spock y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 3 la maquina
#
# El jugador ha elegido jugar spock y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 4 la maquina
#
# El jugador ha elegido jugar spock y la maquina spock
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 5 la maquina
#
# El jugador ha elegido jugar spock y la maquina papel
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 6 la maquina
#
# El jugador ha elegido jugar spock y la maquina lagarto
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 7 la maquina
#
# El jugador ha elegido jugar spock y la maquina tijeras
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 8 la maquina
#
# El jugador ha elegido jugar spock y la maquina piedra
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 9 la maquina
#
# El jugador ha elegido jugar spock y la maquina piedra
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 10 la maquina
#
# El jugador ha elegido jugar spock y la maquina piedra
# ----------------------------------------------------------------------
# partidas ganadas: 0 el jugador vs 11 la maquina
#
# HA GANADO LA MAQUINA! Suerte para la próxima :(

# %% [markdown]
# Si has programado con cabeza, el bonus son simples modificaciones al juego original.

# %% [markdown]
# ## Objetivos
# 1. Uso de bucle
# 2. Captura de datos por consola
# 3. Uso if-elif-else
# 4. Uso de try-except
# 5. Definición de funciones. Programación modular.
# 6. Operadores lógicos.
# 7. Imprimir por consola
# 8. Importación de módulos externos
